# %%
import pandas as pd
import matplotlib.pyplot as plt
india = df[df['Country'] == 'India']
age_groups = ['0-4 years', '5-14 years', '15-24 years', '25-64 years', '65+']
population = [
    india['0-4 years'].values[0],
    india['5-14 years'].values[0],
    india['15-24 years'].values[0],
    india['25-64 years'].values[0],
    india['65+'].values[0]
]

# %%
plt.bar(age_groups, population)
plt.xlabel('Age Groups')
plt.ylabel('Population')
plt.title('Population Distribution by Age Group (India)')
plt.show()
